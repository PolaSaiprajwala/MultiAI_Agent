# %%
# !pip install phidata
# Out:
# Collecting phidata
#   Downloading phidata-2.7.7-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.10/dist-packages (from phidata) (0.16)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.10/dist-packages (from phidata) (3.1.44)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from phidata) (0.28.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from phidata) (2.10.4)
# Collecting pydantic-settings (from phidata)
#   Downloading pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting python-dotenv (from phidata)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from phidata) (6.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from phidata) (13.9.4)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from phidata) (2.2.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from phidata) (0.15.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from phidata) (4.12.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython->phidata) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->phidata) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->phidata) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->phidata) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->phidata) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->phidata) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->phidata) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic->phidata) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->phidata) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->phidata) (2.18.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer->phidata) (8.1.8)
# ERROR: Operation cancelled by user

# %%
GROQ_API_KEY="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"
PHI_API_KEY="phi-eJQcehbz49xj6c1SO8dOv236zO7pPjwiuvK2U67i160"

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"  # Replace with your actual OpenAI API key

# %%
# !pip install duckduckgo_search
# Out:
# Collecting duckduckgo_search
#   Downloading duckduckgo_search-7.2.1-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from duckduckgo_search) (8.1.8)
# Collecting primp>=0.10.0 (from duckduckgo_search)
#   Downloading primp-0.10.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from duckduckgo_search) (5.3.0)
# Downloading duckduckgo_search-7.2.1-py3-none-any.whl (19 kB)
# Downloading primp-0.10.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 43.2 MB/s eta 0:00:00
# Installing collected packages: primp, duckduckgo_search
# Successfully installed duckduckgo_search-7.2.1 primp-0.10.0

# %%
# !pip install --upgrade duckduckgo_search
# Out:
# Requirement already satisfied: duckduckgo_search in /usr/local/lib/python3.10/dist-packages (7.2.1)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.10/dist-packages (from duckduckgo_search) (8.1.8)
# Requirement already satisfied: primp>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from duckduckgo_search) (0.10.0)
# Requirement already satisfied: lxml>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from duckduckgo_search) (5.3.0)

# %%
# !pip install groq
# Out:
# Collecting groq
#   Downloading groq-0.14.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from groq) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from groq) (2.10.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.10/dist-packages (from groq) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->groq) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->groq) (2.27.2)
# Downloading groq-0.14.0-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.5/109.5 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-0.14.0

# %%
# !pip install python-dotenv # Install the python-dotenv package
import os
from dotenv import load_dotenv
import openai
load_dotenv()
openai.api_key = os.getenv("OPENAI_API_KEY")
# Out:
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
# !pip install phidata
# Out:
# Collecting phidata
#   Using cached phidata-2.7.7-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: docstring-parser in /usr/local/lib/python3.10/dist-packages (from phidata) (0.16)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.10/dist-packages (from phidata) (3.1.44)
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from phidata) (0.28.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from phidata) (2.10.4)
# Collecting pydantic-settings (from phidata)
#   Using cached pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from phidata) (1.0.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from phidata) (6.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from phidata) (13.9.4)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from phidata) (2.2.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from phidata) (0.15.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from phidata) (4.12.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython->phidata) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx->phidata) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->phidata) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx->phidata) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->phidata) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx->phidata) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic->phidata) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic->phidata) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->phidata) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->phidata) (2.18.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer->phidata) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer->phidata) (1.5.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython->phidata) (5.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->phidata) (0.1.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->phidata) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx->phidata) (1.2.2)
# Downloading phidata-2.7.7-py3-none-any.whl (699 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 699.6/699.6 kB 13.0 MB/s eta 0:00:00
# Downloading pydantic_settings-2.7.1-py3-none-any.whl (29 kB)
# Installing collected packages: pydantic-settings, phidata
# Successfully installed phidata-2.7.7 pydantic-settings-2.7.1

# %%
import os
os.environ["GROQ_API_KEY"] = "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"
#financial agent
from phi.agent import Agent
from phi.model.groq import Groq
from phi.tools.yfinance import YFinanceTools
from phi.tools.duckduckgo import DuckDuckGo

##websearch agent

websearch_agent = Agent(
    name="websearch agent",
    role="search the web for information",
    model=Groq(id="llama-3.3-70b-versatile"),
    tools=[DuckDuckGo()],
    instructions=["always include sources"],
    show_tools_calls=True,
    markdown=True,
)

##financial agent

finance_agent = Agent(
    name="finance agent",
    role="provide financial information",
    model=Groq(id="llama-3.3-70b-versatile"),
    tools=[YFinanceTools(stock_price=True, analyst_recommendations=True, stock_fundamentals=True,
                         company_news=True),
  ],
  instructions=["use tables to display the data"],
  show_tools_calls=True,
  markdown=True,

)

multi_ai_agent=Agent(
    team=[websearch_agent,finance_agent],
    model=Groq(id="llama-3.3-70b-versatile"),
    instructions=["always include sources","use tables to display the data","When asked to summarize news, focus on the main points and key events.",  # Add this line
        "For TSLA news, search for recent articles and reports about the company." ],
    show_tools_calls=True,
    markdown=True,
)
multi_ai_agent.print_response("summarize analyst recommendation and share the latest news for TSLA",stream=True)


result = multi_ai_agent.run(
    """
    Please provide a summary of analyst recommendations for TSLA.
    Then, share the latest news for TSLA, focusing on the main points and key events.

    Use the following tools:
    - YFinanceTools for analyst recommendations
    - DuckDuckGo for the latest news
    """,
    stream=False
)
print(result)
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# content="### Latest News for TSLA\nHere are the latest news articles for TSLA:\n1. **TSLA's Q4 Earnings Report**: TSLA reported a significant increase in revenue and net income for the fourth quarter, beating analyst expectations.\n2. **TSLA's Autonomous Driving Technology**: TSLA announced a major update to its autonomous driving technology, which is expected to improve the safety and efficiency of its vehicles.\n3. **TSLA's Expansion into New Markets**: TSLA announced plans to expand into new markets, including Europe and Asia, as part of its efforts to increase global sales.\n4. **TSLA's Investment in Renewable Energy**: TSLA announced a significant investment in renewable energy, with plans to build new solar and wind farms to power its manufacturing facilities.\n5. **TSLA's Partnership with Major Automaker**: TSLA announced a partnership with a major automaker to develop new electric vehicles, which is expected to increase its market share and competitiveness." content_type='str' event='RunResponse' messages=[Message(role='system', content='## You are the leader of a team of AI Agents.\n  - You can either respond directly or transfer tasks to other Agents in your team depending on the tools available to them.\n  - If you transfer a task to another Agent, make sure to include a clear description of the task and the expected output.\n  - You must always validate the output of the other Agents before responding to the user, you can re-assign the task if you are not satisfied with the result.\n\n## Instructions\n- always include sources\n- use tables to display the data\n- When asked to summarize news, focus on the main points and key events.\n- For TSLA news, search for recent articles and reports about the company.\n- Use markdown to format your answers.\n\n## Agents in your team:\nYou can transfer tasks to the following agents:\nAgent 1:\nName: websearch agent\nRole: search the web for information\nAvailable tools: duckduckgo_search, duckduckgo_news\n\nAgent 2:\nName: finance agent\nRole: provide financial information\nAvailable tools: get_current_stock_price, get_stock_fundamentals, get_analyst_recommendations, get_company_news', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={}, references=None, created_at=1736419360), Message(role='user', content='\n    Please provide a summary of analyst recommendations for TSLA.\n    Then, share the latest news for TSLA, focusing on the main points and key events.\n\n    Use the following tools:\n    - YFinanceTools for analyst recommendations\n    - DuckDuckGo for the latest news\n    ', name=None, tool_call_id=None, tool_calls=None, audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={}, references=None, created_at=1736419360), Message(role='assistant', content=None, name=None, tool_call_id=None, tool_calls=[{'id': 'call_zynf', 'function': {'arguments': '{"task_description": "Provide a summary of analyst recommendations for TSLA using YFinanceTools", "expected_output": "A summary of analyst recommendations for TSLA", "additional_information": "Use YFinanceTools to get the analyst recommendations"}', 'name': 'transfer_task_to_finance_agent'}, 'type': 'function'}, {'id': 'call_akza', 'function': {'arguments': '{"task_description": "Search for the latest news for TSLA using DuckDuckGo", "expected_output": "The latest news articles for TSLA", "additional_information": "Use DuckDuckGo to search for recent articles and reports about TSLA"}', 'name': 'transfer_task_to_websearch_agent'}, 'type': 'function'}], audio=None, images=None, videos=None, tool_name=None, tool_args=None, tool_call_error=None, stop_after_tool_call=False, metrics={'time': 14.451018704000035, 'input_tokens': 994, 'prompt_tokens': 994, 'output_tokens': 131, 'completion_tokens': 131, 'total_tokens': 1125, 'completion_time ...

# %%
# !pip install fastapi
# Out:
# Collecting fastapi
#   Downloading fastapi-0.115.6-py3-none-any.whl.metadata (27 kB)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from fastapi) (2.10.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi) (4.12.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.27.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from starlette<0.42.0,>=0.40.0->fastapi) (3.7.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (1.2.2)
# Downloading fastapi-0.115.6-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 5.9 MB/s eta 0:00:00
# Downloading starlette-0.41.3-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: starlette, fastapi
# Successfully installed fastapi-0.115.6 starlette-0.41.3
